# %%
from typing import Any

from longport.openapi import AdjustType, CalcIndex, Config, Period, QuoteContext
import pandas as pd

config = Config.from_env()
quote_ctx = QuoteContext(config)


def fetch_with_indicators(
    symbol: str = "510300.SH",
    period: Any = Period.Day,
    count: int = 200,
    adjust: Any = AdjustType.ForwardAdjust,
):
    candles_raw = quote_ctx.candlesticks(symbol, period, count, adjust)

    if not candles_raw:
        raise ValueError(f"未获取到 {symbol} 的K线数据")

    rows = []
    for candle in candles_raw:
        rows.append(
            {
                "symbol": symbol,
                "timestamp": candle.timestamp,
                "open": float(candle.open),
                "high": float(candle.high),
                "low": float(candle.low),
                "close": float(candle.close),
                "volume": candle.volume,
                "turnover": float(candle.turnover),
            }
        )

    candles = pd.DataFrame(rows)

    return candles


df = fetch_with_indicators()
display(df.info())
# Out:
# +----------+--------------------------------------------------------------------------------------------------+
# | US       | Nasdaq Basic                                                                                     |
# |----------+--------------------------------------------------------------------------------------------------|
# | HK       | LV1 Real-time Quotes                                                                             |
# |----------+--------------------------------------------------------------------------------------------------|
# | CN       | LV1 Real-time Quotes                                                                             |
# |----------+--------------------------------------------------------------------------------------------------|
# | USOption | You do not have access to the market's Open API data. Please visit the Quotes Store to purchase. |
# +----------+--------------------------------------------------------------------------------------------<class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   symbol     200 non-null    object
#  1   timestamp  200 non-null    datetime64[ns]
#  2   open       200 non-null    float64
#  3   high       200 non-null    float64
#  4   low        200 non-null    float64
#  5   close      200 non-null    float64
#  6   volume     200 non-null    int64
#  7   turnover   200 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(1)
# memory usage: 12.6+ KB
# ------+
# None

# %%
df = fetch_with_indicators()
display(df.tail())
# Out:
#         symbol  timestamp   open   high    low  close   volume      turnover  \
# 195  510300.SH 2025-10-22  4.690  4.708  4.668  4.695  5544842  2.601506e+09
# 196  510300.SH 2025-10-23  4.687  4.719  4.642  4.713  6993428  3.267824e+09
# 197  510300.SH 2025-10-24  4.728  4.772  4.727  4.770  8653036  4.110591e+09
# 198  510300.SH 2025-10-27  4.808  4.831  4.796  4.826  7585249  3.652923e+09
# 199  510300.SH 2025-10-28  4.815  4.850  4.792  4.802  7259491  3.497089e+09
#
#                      datetime    ema_20      macd  macd_signal  macd_hist  \
# 195 2025-10-22 00:00:00+00:00  4.662842  0.040980     0.054070  -0.013090
# 196 2025-10-23 00:00:00+00:00  4.667619  0.040414     0.051339  -0.010925
# 197 2025-10-24 00:00:00+00:00  4.677370  0.044057     0.049882  -0.005825
# 198 2025-10-27 00:00:00+00:00  4.691525  0.050877     0.050081   0.000796
# 199 2025-10-28 00:00:00+00:00  4.702046  0.053726     0.050810   0.002915
#
#         rsi_14
# 195  55.161046
# 196  56.553950
# 197  60.715663
# 198  64.330712
# 199  61.709775

# %%
candles_raw = quote_ctx.candlesticks("510300.SH", Period.Day, 10, AdjustType.ForwardAdjust)
display(candles_raw)
# Out:
# [Candlestick { close: 4.706, open: 4.648, low: 4.627, high: 4.715, volume: 9974013, turnover: 4649845988.000, timestamp: "2025-10-14T16:00:00Z", trade_session: Intraday },
#  Candlestick { close: 4.721, open: 4.689, low: 4.689, high: 4.747, volume: 8124633, turnover: 3835512324.000, timestamp: "2025-10-15T16:00:00Z", trade_session: Intraday },
#  Candlestick { close: 4.624, open: 4.715, low: 4.612, high: 4.724, volume: 8400582, turnover: 3909864092.000, timestamp: "2025-10-16T16:00:00Z", trade_session: Intraday },
#  Candlestick { close: 4.640, open: 4.651, low: 4.624, high: 4.678, volume: 7644178, turnover: 3554256321.000, timestamp: "2025-10-19T16:00:00Z", trade_session: Intraday },
#  Candlestick { close: 4.710, open: 4.656, low: 4.652, high: 4.723, volume: 9598685, turnover: 4511371971.000, timestamp: "2025-10-20T16:00:00Z", trade_session: Intraday },
#  Candlestick { close: 4.695, open: 4.690, low: 4.668, high: 4.708, volume: 5544842, turnover: 2601506365.000, timestamp: "2025-10-21T16:00:00Z", trade_session: Intraday },
#  Candlestick { close: 4.713, open: 4.687, low: 4.642, high: 4.719, volume: 6993428, turnover: 3267824361.000, timestamp: "2025-10-22T16:00:00Z", trade_session: Intraday },
#  Candlestick { close: 4.770, open: 4.728, low: 4.727, high: 4.772, volume: 8653036, turnover: 4110591097.000, timestamp: "2025-10-23T16:00:00Z", trade_session: Intraday },
#  Candlestick { close: 4.826, open: 4.808, low: 4.796, high: 4.831, volume: 7585249, turnover: 3652922851.000, timestamp: "2025-10-26T16:00:00Z", trade_session: Intraday },
#  Candlestick { close: 4.802, open: 4.815, low: 4.792, high: 4.850, volume: 7259491, turnover: 3497088820.000, timestamp: "2025-10-27T16:00:00Z", trade_session: Intraday }]

# %%
from longport.openapi import AdjustType, Config, Period, QuoteContext

info = quote_ctx.calc_indexes(
    ["510300.SH"],
    [CalcIndex.VolumeRatio, CalcIndex.TurnoverRate,],
)
display(info)
# Out:
# [SecurityCalcIndex { symbol: "510300.SH", last_done: None, change_value: None, change_rate: None, volume: None, turnover: None, ytd_change_rate: None, turnover_rate: Some(0.02), total_market_value: None, capital_flow: None, amplitude: None, volume_ratio: Some(0.95), pe_ttm_ratio: None, pb_ratio: None, dividend_ratio_ttm: None, five_day_change_rate: None, ten_day_change_rate: None, half_year_change_rate: None, five_minutes_change_rate: None, expiry_date: None, strike_price: None, upper_strike_price: None, lower_strike_price: None, outstanding_qty: None, outstanding_ratio: None, premium: None, itm_otm: None, implied_volatility: None, warrant_delta: None, call_price: None, to_call_price: None, effective_leverage: None, leverage_ratio: None, conversion_ratio: None, balance_point: None, open_interest: None, delta: None, gamma: None, theta: None, vega: None, rho: None }]

# %%
# 获取账户资金
# https://open.longportapp.com/docs/trade/asset/account
from longport.openapi import Config, TradeContext

config = Config.from_env()
ctx = TradeContext(config)
resp = ctx.account_balance()
print(resp)
# Out:
# [AccountBalance { total_cash: 107.69, max_finance_amount: 8000.00, remaining_finance_amount: 8000.00, risk_level: 0, margin_call: 0, currency: "HKD", cash_infos: [CashInfo { withdraw_cash: 13.86, available_cash: 13.86, frozen_cash: 0.00, settling_cash: 0.00, currency: "USD" }, CashInfo { withdraw_cash: 0.00, available_cash: 0.00, frozen_cash: 0.00, settling_cash: 0.00, currency: "HKD" }], net_assets: 32086.71, init_margin: 31979.02, maintenance_margin: 30380.07, buy_power: 107.69, frozen_transaction_fees: [] }]

# %%
from longport.openapi import Config, QuoteContext

config = Config.from_env()
ctx = QuoteContext(config)
resp = ctx.watchlist()
print(resp)
# Out:
# +----------+--------------------------------------------------------------------------------------------------+
# | US       | Nasdaq Basic                                                                                     |
# |----------+--------------------------------------------------------------------------------------------------|
# | USOption | You do not have access to the market's Open API data. Please visit the Quotes Store to purchase. |
# |----------+--------------------------------------------------------------------------------------------------|
# | CN       | LV1 Real-time Quotes                                                                             |
# |----------+--------------------------------------------------------------------------------------------------|
# | HK       | LV1 Real-time Quotes                                                                             |
# +----------+--------------------------------------------------------------------------------------------------+
# [WatchlistGroup { id: 2574861, name: "all", securities: [WatchlistSecurity { symbol: "3690.HK", market: HK, name: "MEITUAN", watched_price: Some(101.1), watched_at: "2025-10-28T01:16:33Z" }, WatchlistSecurity { symbol: "QQQ.US", market: US, name: "Invesco QQQ Trust", watched_price: Some(628.09), watched_at: "2025-10-28T00:29:49Z" }, WatchlistSecurity { symbol: "ALAB.US", market: US, name: "Astera Labs", watched_price: Some(157.51), watched_at: "2025-10-21T23:35:19Z" }, WatchlistSecurity { symbol: "CRWV.US", market: US, name: "Coreweave", watched_price: Some(125.06), watched_at: "2025-10-21T23:34:32Z" }, WatchlistSecurity { symbol: "EOSE.US", market: US, name: "EOS Energy Enterprises", watched_price: Some(16.98), watched_at: "2025-10-15T13:22:13Z" }, WatchlistSecurity { symbol: "UUUU.US", market: US, name: "Energy Fuels", watched_price: Some(26.23), watched_at: "2025-10-15T13:19:33Z" }, WatchlistSecurity { symbol: "IONQ.US", market: US, name: "IonQ", watched_price: Some(82.09), watched_at: "2025-10-14T00:32:57Z" }, WatchlistSecurity { symbol: "IREN.US", market: US, name: "IREN", watched_price: Some(64.14), watched_at: "2025-10-14T00:22:32Z" }, WatchlistSecurity { symbol: "HMY.US", market: US, name: "Harmony Gold Mining", watched_price: Some(19.364), watched_at: "2025-10-13T14:07:37Z" }, WatchlistSecurity { symbol: "NET.US", market: US, name: "CloudFlare", watched_price: Some(216.34), watched_at: "2025-09-28T13:33:44Z" }, WatchlistSecurity { symbol: "OKLO.US", market: US, name: "Oklo", watched_price: Some(135.23), watched_at: "2025-09-21T10:38:35Z" }, WatchlistSecurity { symbol: "LKNCY.US", market: US, name: "Luckin Coffee", watched_price: Some(38.5), watched_at: "2025-08-16T10:05:24Z" }, WatchlistSecurity { symbol: "MP.US", market: US, name: "MP Materials", watched_price: Some(72.69), watched_at: "2025-08-11T21:25:54Z" }, WatchlistSecurity { symbol: "2400.HK", market: HK, name: "XD INC", watched_price: Some(70.8), watched_at: "2025-08-05T21:34:29Z" }, WatchlistSecurity { symbol: "700.HK", market: HK, name: "TENCENT", watched_price: Some(521), watched_at: "2025-05-15T00:31:25Z" }, WatchlistSecurity { symbol: "1801.HK", market: HK, name: "INNOVENT BIO", watched_price: Some(39.45), watched_at: "2025-03-12T06:22:48Z" }, WatchlistSecurity { symbol: "966.HK", market: HK, name: "CHINA TAIPING", watched_price: Some(12.04), watched_at: "2025-02-21T05:44:36Z" }, WatchlistSecurity { symbol: "1347.HK", market: HK, name: "HUA HONG SEMI", watched_price: Some(36.65), watched_at: "2025-02-19T04:07:56Z" }, WatchlistSecurity { symbol: "ASTS.US", market: US, name: "AST SpaceMobile", watched_price: Some(24.71), watched_at: "2025-02-06T00:23:19Z" }, WatchlistSecurity { symbol: "HOOD.US", market: US, name: "Robinhood", watched_price: Some(54.2), watched_at: "2025-02-06T00:22:35Z" }, WatchlistSecurity { symbol: "ARM.US", market: US, name: "Arm", watched_price: Some(161.18), watched_at: "2025-02-04T15:12:02Z" }, WatchlistSecurity { symbol: "9961.HK", market: HK, name: "TRIP.COM-S", watched_price: Some(540), watched_at: "2025-02-03T03:02:41Z" }, WatchlistSecurity { symbol: "1024.HK", market: HK, name: "KUAISHOU-W", watched_price: Some(40.65), watched_at: "2025-02-03T03:02:08Z" }, WatchlistSecurity { symbol: "3896.HK", market: HK, name: "KINGSOFT CLOUD", watched_price: Some(7.57), watched_at: "2025-02-03T02:32:11Z" }, WatchlistSecurity { symbol: "9992.HK", market: HK, name: "POP MART", watched_price: Some(92.05), watched_at: "2025-02-03T02:31:58Z" }, WatchlistSecurity { symbol: "9880.HK", market: HK, name: "UBTECH ROBOTICS", watched_price: Some(74.7), watched_at: "2025-02-03T02:31:27Z" }, WatchlistSecurity { symbol: "981.HK", market: HK, name: "SMIC", watched_price: Some(39.95), watched_at: "2025-02-03T02:28:00Z" }, WatchlistSecurity { symbol: "PLTR.US", market: US, name: "Palantir Tech", watched_price: Some(77.18), watched_at: "2024-12-31T01:19:17Z" }, WatchlistSecurity { symbol: "1810.HK", market: HK, name: "XIAOMI-W", watched_price: Some(34.45), watc ...

# %%
display(resp)
# Out:
# [WatchlistGroup { id: 2574861, name: "all", securities: [WatchlistSecurity { symbol: "3690.HK", market: HK, name: "MEITUAN", watched_price: Some(101.1), watched_at: "2025-10-28T01:16:33Z" }, WatchlistSecurity { symbol: "QQQ.US", market: US, name: "Invesco QQQ Trust", watched_price: Some(628.09), watched_at: "2025-10-28T00:29:49Z" }, WatchlistSecurity { symbol: "ALAB.US", market: US, name: "Astera Labs", watched_price: Some(157.51), watched_at: "2025-10-21T23:35:19Z" }, WatchlistSecurity { symbol: "CRWV.US", market: US, name: "Coreweave", watched_price: Some(125.06), watched_at: "2025-10-21T23:34:32Z" }, WatchlistSecurity { symbol: "EOSE.US", market: US, name: "EOS Energy Enterprises", watched_price: Some(16.98), watched_at: "2025-10-15T13:22:13Z" }, WatchlistSecurity { symbol: "UUUU.US", market: US, name: "Energy Fuels", watched_price: Some(26.23), watched_at: "2025-10-15T13:19:33Z" }, WatchlistSecurity { symbol: "IONQ.US", market: US, name: "IonQ", watched_price: Some(82.09), watched_at: "2025-10-14T00:32:57Z" }, WatchlistSecurity { symbol: "IREN.US", market: US, name: "IREN", watched_price: Some(64.14), watched_at: "2025-10-14T00:22:32Z" }, WatchlistSecurity { symbol: "HMY.US", market: US, name: "Harmony Gold Mining", watched_price: Some(19.364), watched_at: "2025-10-13T14:07:37Z" }, WatchlistSecurity { symbol: "NET.US", market: US, name: "CloudFlare", watched_price: Some(216.34), watched_at: "2025-09-28T13:33:44Z" }, WatchlistSecurity { symbol: "OKLO.US", market: US, name: "Oklo", watched_price: Some(135.23), watched_at: "2025-09-21T10:38:35Z" }, WatchlistSecurity { symbol: "LKNCY.US", market: US, name: "Luckin Coffee", watched_price: Some(38.5), watched_at: "2025-08-16T10:05:24Z" }, WatchlistSecurity { symbol: "MP.US", market: US, name: "MP Materials", watched_price: Some(72.69), watched_at: "2025-08-11T21:25:54Z" }, WatchlistSecurity { symbol: "2400.HK", market: HK, name: "XD INC", watched_price: Some(70.8), watched_at: "2025-08-05T21:34:29Z" }, WatchlistSecurity { symbol: "700.HK", market: HK, name: "TENCENT", watched_price: Some(521), watched_at: "2025-05-15T00:31:25Z" }, WatchlistSecurity { symbol: "1801.HK", market: HK, name: "INNOVENT BIO", watched_price: Some(39.45), watched_at: "2025-03-12T06:22:48Z" }, WatchlistSecurity { symbol: "966.HK", market: HK, name: "CHINA TAIPING", watched_price: Some(12.04), watched_at: "2025-02-21T05:44:36Z" }, WatchlistSecurity { symbol: "1347.HK", market: HK, name: "HUA HONG SEMI", watched_price: Some(36.65), watched_at: "2025-02-19T04:07:56Z" }, WatchlistSecurity { symbol: "ASTS.US", market: US, name: "AST SpaceMobile", watched_price: Some(24.71), watched_at: "2025-02-06T00:23:19Z" }, WatchlistSecurity { symbol: "HOOD.US", market: US, name: "Robinhood", watched_price: Some(54.2), watched_at: "2025-02-06T00:22:35Z" }, WatchlistSecurity { symbol: "ARM.US", market: US, name: "Arm", watched_price: Some(161.18), watched_at: "2025-02-04T15:12:02Z" }, WatchlistSecurity { symbol: "9961.HK", market: HK, name: "TRIP.COM-S", watched_price: Some(540), watched_at: "2025-02-03T03:02:41Z" }, WatchlistSecurity { symbol: "1024.HK", market: HK, name: "KUAISHOU-W", watched_price: Some(40.65), watched_at: "2025-02-03T03:02:08Z" }, WatchlistSecurity { symbol: "3896.HK", market: HK, name: "KINGSOFT CLOUD", watched_price: Some(7.57), watched_at: "2025-02-03T02:32:11Z" }, WatchlistSecurity { symbol: "9992.HK", market: HK, name: "POP MART", watched_price: Some(92.05), watched_at: "2025-02-03T02:31:58Z" }, WatchlistSecurity { symbol: "9880.HK", market: HK, name: "UBTECH ROBOTICS", watched_price: Some(74.7), watched_at: "2025-02-03T02:31:27Z" }, WatchlistSecurity { symbol: "981.HK", market: HK, name: "SMIC", watched_price: Some(39.95), watched_at: "2025-02-03T02:28:00Z" }, WatchlistSecurity { symbol: "PLTR.US", market: US, name: "Palantir Tech", watched_price: Some(77.18), watched_at: "2024-12-31T01:19:17Z" }, WatchlistSecurity { symbol: "1810.HK", market: HK, name: "XIAOMI-W", watched_price: Some(34.45), watc ...
#  WatchlistGroup { id: 2804175, name: "cn", securities: [] },
#  WatchlistGroup { id: 3867961, name: "ETF", securities: [] },
#  WatchlistGroup { id: 3974095, name: "T0ETF", securities: [] },
#  WatchlistGroup { id: 2574862, name: "hk", securities: [WatchlistSecurity { symbol: "3690.HK", market: HK, name: "MEITUAN", watched_price: Some(101.1), watched_at: "2025-10-28T01:16:33Z" }, WatchlistSecurity { symbol: "2400.HK", market: HK, name: "XD INC", watched_price: Some(70.8), watched_at: "2025-08-05T21:34:29Z" }, WatchlistSecurity { symbol: "700.HK", market: HK, name: "TENCENT", watched_price: Some(521), watched_at: "2025-05-15T00:31:25Z" }, WatchlistSecurity { symbol: "1801.HK", market: HK, name: "INNOVENT BIO", watched_price: Some(39.45), watched_at: "2025-03-12T06:22:48Z" }, WatchlistSecurity { symbol: "966.HK", market: HK, name: "CHINA TAIPING", watched_price: Some(12.04), watched_at: "2025-02-21T05:44:36Z" }, WatchlistSecurity { symbol: "1347.HK", market: HK, name: "HUA HONG SEMI", watched_price: Some(36.65), watched_at: "2025-02-19T04:07:56Z" }, WatchlistSecurity { symbol: "9961.HK", market: HK, name: "TRIP.COM-S", watched_price: Some(540), watched_at: "2025-02-03T03:02:41Z" }, WatchlistSecurity { symbol: "1024.HK", market: HK, name: "KUAISHOU-W", watched_price: Some(40.65), watched_at: "2025-02-03T03:02:08Z" }, WatchlistSecurity { symbol: "3896.HK", market: HK, name: "KINGSOFT CLOUD", watched_price: Some(7.57), watched_at: "2025-02-03T02:32:11Z" }, WatchlistSecurity { symbol: "9992.HK", market: HK, name: "POP MART", watched_price: Some(92.05), watched_at: "2025-02-03T02:31:58Z" }, WatchlistSecurity { symbol: "9880.HK", market: HK, name: "UBTECH ROBOTICS", watched_price: Some(74.7), watched_at: "2025-02-03T02:31:27Z" }, WatchlistSecurity { symbol: "981.HK", market: HK, name: "SMIC", watched_price: Some(39.95), watched_at: "2025-02-03T02:28:00Z" }, WatchlistSecurity { symbol: "1810.HK", market: HK, name: "XIAOMI-W", watched_price: Some(34.45), watched_at: "2024-12-31T01:19:00Z" }, WatchlistSecurity { symbol: "9988.HK", market: HK, name: "BABA-W", watched_price: Some(81.95), watched_at: "2024-12-05T08:12:53Z" }] },
#  WatchlistGroup { id: 2574860, name: "us", securities: [WatchlistSecurity { symbol: "QQQ.US", market: US, name: "Invesco QQQ Trust", watched_price: Some(628.09), watched_at: "2025-10-28T00:29:49Z" }, WatchlistSecurity { symbol: "ALAB.US", market: US, name: "Astera Labs", watched_price: Some(157.51), watched_at: "2025-10-21T23:35:19Z" }, WatchlistSecurity { symbol: "CRWV.US", market: US, name: "Coreweave", watched_price: Some(125.06), watched_at: "2025-10-21T23:34:32Z" }, WatchlistSecurity { symbol: "EOSE.US", market: US, name: "EOS Energy Enterprises", watched_price: Some(16.98), watched_at: "2025-10-15T13:22:13Z" }, WatchlistSecurity { symbol: "UUUU.US", market: US, name: "Energy Fuels", watched_price: Some(26.23), watched_at: "2025-10-15T13:19:33Z" }, WatchlistSecurity { symbol: "IONQ.US", market: US, name: "IonQ", watched_price: Some(82.09), watched_at: "2025-10-14T00:32:57Z" }, WatchlistSecurity { symbol: "IREN.US", market: US, name: "IREN", watched_price: Some(64.14), watched_at: "2025-10-14T00:22:32Z" }, WatchlistSecurity { symbol: "HMY.US", market: US, name: "Harmony Gold Mining", watched_price: Some(19.364), watched_at: "2025-10-13T14:07:37Z" }, WatchlistSecurity { symbol: "NET.US", market: US, name: "CloudFlare", watched_price: Some(216.34), watched_at: "2025-09-28T13:33:44Z" }, WatchlistSecurity { symbol: "OKLO.US", market: US, name: "Oklo", watched_price: Some(135.23), watched_at: "2025-09-21T10:38:35Z" }, WatchlistSecurity { symbol: "LKNCY.US", market: US, name: "Luckin Coffee", watched_price: Some(38.5), watched_at: "2025-08-16T10:05:24Z" }, WatchlistSecurity { symbol: "MP.US", market: US, name: "MP Materials", watched_price: Some(72.69), watched_at: "2025-08-11T21:25:54Z" }, WatchlistSecurity { symbol: "ASTS.US", market: US, name: "AST SpaceMobile", watched_price: Some(24.71), watched_at: "2025-02-06T00:23:19Z" }, WatchlistSecurity { symbol: "HOOD.US", market: US, name: "Robinhood", watched_price: Some(54.2), watched_at: "2025-02-06T00:22:35Z" }, WatchlistSecurity { symbol: "ARM.US", market: US, name: "Arm", watched_price: Some(161.18), watched_at: "2025-02-04T15:12:02Z" }, WatchlistSecurity { symbol: "PLTR.US", market: US, name: "Palantir Tech", watched_price: Some(77.18), watched_at: "2024-12-31T01:19:17Z" }, WatchlistSecurity { symbol: "AMD.US", market: US, name: "AMD", watched_price: Some(143.99), watched_at: "2024-12-05T08:12:53Z" }, WatchlistSecurity { symbol: "AVGO.US", market: US, name: "Broadcom", watched_price: Some(170.56), watched_at: "2024-12-05T08:12:53Z" }, WatchlistSecurity { symbol: "PDD.US", market: US, name: "PDD", watched_price: Some(98.71), watched_at: "2024-12-05T08:12:53Z" }] },
#  WatchlistGroup { id: -6, name: "holdings", securities: [] }]

# %%
from longport.openapi import Config, QuoteContext, SecuritiesUpdateMode

config = Config.from_env()
ctx = QuoteContext(config)

df = pd.read_csv("./data/etf.csv")
df_t1 = df[df["sort"] == "T1"]["sym"].to_list()
df_t0 = df[df["sort"] == "T0"]["sym"].to_list()

ctx.update_watchlist_group(
	3974095,
	securities=df_t0,
	mode=SecuritiesUpdateMode.Add,
)
ctx.update_watchlist_group(3867961, securities=df_t1, mode=SecuritiesUpdateMode.Add)
# Out:
# +----------+--------------------------------------------------------------------------------------------------+
# | US       | Nasdaq Basic                                                                                     |
# |----------+--------------------------------------------------------------------------------------------------|
# | CN       | LV1 Real-time Quotes                                                                             |
# |----------+--------------------------------------------------------------------------------------------------|
# | HK       | LV1 Real-time Quotes                                                                             |
# |----------+--------------------------------------------------------------------------------------------------|
# | USOption | You do not have access to the market's Open API data. Please visit the Quotes Store to purchase. |
# +----------+--------------------------------------------------------------------------------------------------+
