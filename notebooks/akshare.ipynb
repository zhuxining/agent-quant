# %%
import akshare as ak

stock_df = ak.rv_from_stock_zh_a_hist_min_em(
	symbol="000001",
	start_date="2021-10-20 09:30:00",
	end_date="2024-11-01 15:00:00",
	period="5",
	adjust="",
)
volatility_yz_rv_df = ak.volatility_yz_rv(stock_df)
display(volatility_yz_rv_df)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 11
#       1 import akshare as ak
#       4 stock_df = ak.rv_from_stock_zh_a_hist_min_em(
#       5 	symbol="000001",
#       6 	start_date="2021-10-20 09:30:00",
#    (...)      9 	adjust="",
#      10 )
# ---> 11 volatility_yz_rv_df = ak.volatility_yz_rv(stock_df)
#      12 display(volatility_yz_rv_df)
#
# File ~/Code/agent-quant/.venv/lib/python3.13/site-packages/akshare/cal/rv.py:144, in volatility_yz_rv(data)
#     142 rs_var = data["RS"].groupby(pd.Grouper(freq="1D")).mean().dropna()
#     143 vc_and_vo = data[["oi", "ci"]].groupby(pd.Grouper(freq="1D")).var().dropna()
# --> 144 n = int(len(data) / len(rs_var))
#     145 k = 0.34 / (1.34 + (n + 1) / (n - 1))
#     146 yang_zhang_rv = np.sqrt((1 - k) * rs_var + vc_and_vo["oi"] + vc_and_vo["ci"] * k)
#
# ZeroDivisionError: division by zero
